# %% [markdown]
# # Démonstration de la recherche hybride (BM25 + vecteurs)

# %%
from src.services.ingest import ingest
from src.services.hybrid_search import hybrid_search

ingest(category="cs.CL", max_results=1)
results = hybrid_search("transformer neural networks", top_k=3)
for r in results:
    print(r["title"], "score:", r["score"])
    print(r["text"][:300], "...\n")
